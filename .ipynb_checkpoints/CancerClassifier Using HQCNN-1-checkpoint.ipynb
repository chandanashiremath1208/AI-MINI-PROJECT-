# %% [markdown]
# <a href="https://colab.research.google.com/github/chandanashiremath1208/AI-MINI-PROJECT-/blob/main/.ipynb_checkpoints/CancerClassifier%20Using%20HQCNN-1-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Load required libraries

# %%
import os
import random

import numpy as np
import pandas as pd

from skimage import io

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.1 Required Functions

# %%
def matrix_confusion(yt, yp):
    data = {'Y_Real': yt,
            'Y_Prediccion': yp}

    df = pd.DataFrame(data, columns=['Y_Real','Y_Prediccion'])
    confusion_matrix = pd.crosstab(df['Y_Real'], df['Y_Prediccion'], rownames=['Real'], colnames=['Predicted'])
    sns.heatmap(confusion_matrix, annot=True, fmt='g')

    plt.show()

# %% [markdown]
# ## 2. Read Data

# %% [markdown]
# ### 2.1 Read Labels (Y)

# %%
data = pd.read_csv("https://raw.githubusercontent.com/AnIsAsPe/ClassificadorCancerEsofago/master/Datos/ClasesImagenes.csv", usecols=[1,2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5063 entries, 0 to 5062
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   image_filename  5063 non-null   object
#  1   class_number    5063 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 79.2+ KB

# %%
data['class_number'].value_counts(sort=False)
# Out:
# class_number
# 0    1469
# 1    3594
# Name: count, dtype: int64

# %% [markdown]
# Class 0 belongs to Healthy Tissue y Class 1 to Cancerous Tissue

# %%
Y = data['class_number']

# %% [markdown]
# ### 2.2 Read Images (X)

# %%
data['image_filename']
# Out:
# 0          im_4_0.png
# 1         im_21_0.png
# 2          im_9_0.png
# 3          im_8_0.png
# 4         im_15_0.png
#             ...
# 5058    im_114_55.png
# 5059      im_7_55.png
# 5060     im_52_55.png
# 5061     im_10_55.png
# 5062    im_111_55.png
# Name: image_filename, Length: 5063, dtype: object

# %% [markdown]
# ## Images can be dowloaded from:
# https://github.com/contepablod/QCNNCancerClassifier/tree/master/CarpetaImagenes
#
# We read them from local disk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'AI MINI PROJECT '
# 'BREAST CANCER DIAGNOSIS'
# 'Breast Cancer Diagnosis Architecture.drawio'
# 'breast_cancer_diagnosis_code (1).ipynb'
#  breast_cancer_diagnosis_code.ipynb
# 'Breast Cancer Diagnosis Report.docx'
#  Cancer-Image-Classifier-Using-HQCNN-main
# 'CAPESTONE PROJECT ARCHTECTURE DIAGRAM.drawio'
# 'CAPESTONE PROJECT ARCHTECTURE DIAGRAM.drawio.png'
# 'Chandana S Hiremath aadhar card .pdf'
# 'CHANDANA S HIREMATH.pdf'
# 'CHANDANA S HIREMATH RESUME 17TH JULY 2025.pdf'
#  Classroom
# 'Colab Notebooks'
#  Dentalxrays
#  ENG22AM0172_C1.pdf.pdf
# 'ENG22AM0172 PEC PPT EXPLANATION.pptx'
# 'ENG22AM0172 PEC PPT.pptx'
# 'eng skit (The Time Travel).mp4'
# 'ER DIAGRAM FINAL.drawio'
# 'ER IDAGRAM FOR BLOOD BANK MANAGEMENT SYSTEM.drawio'
# 'INTRODUCTION VIDEO (1).mp4'
# 'MINOR PROJECT ARCHITECTURE.drawio'
# 'Minor Project Report Content(4).pdf'
# 'skit final.mp4'
# 'SPECIAL TOPIC FLOW CHART'
#  VID20250718130322.mp4

# %%
# !ls "/content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main"
# Out:
# 'Image Cancer Classifier Using HQCNN.ipynb'
#  Imagenes_Clasificadas_Random_Split
#  Images
#  imagesubset.ipynb
# 'main code part CancerClassifier Using HQCNN-1.ipynb'
#  README.md

# %%
path = "/content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Images/"

# %%
import os
from skimage.io import imread
from skimage.transform import resize
from tqdm import tqdm

path = "/content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Images"

img = []
for fname in tqdm(data['image_filename']):
    image = imread(os.path.join(path, fname), as_gray=True)
    image = resize(image, (260, 260))   # resize to match your next step
    img.append(image)
# Out:
# 100%|██████████| 5063/5063 [54:16<00:00,  1.55it/s]

# %%
import numpy as np
img = np.array(img)
print(img.shape)  # should be (5063, 260, 260)
# Out:
# (5063, 260, 260)

# %% [markdown]
# - Dimension 0: 260 up-to-down pixels rows
# - Dimension 1: 260 left-to-right pixel columns

# %% [markdown]
# ####  Images to vectors

# %%
img.shape
# Out:
# (5063, 260, 260)

# %%
img[0].shape
# Out:
# (260, 260)

# %%
IMG = np.stack(img, axis=0)
IMG.shape
# Out:
# (5063, 260, 260)

# %% [markdown]
# Then flatten the 2D matrix (260x260 pixels) of each image, to obtain one vector per image.

# %%
X = IMG.reshape(5063, -1) # se puede poner 67600 en vez de -1
X.shape
# Out:
# (5063, 67600)

# %% [markdown]
# ##### Image Visualizer

# %%
byClass = data.groupby('class_number')

n = 20
c = random.sample(byClass.get_group(1).index.tolist(), n)
s = random.sample(byClass.get_group(0).index.tolist(), n)


fig = plt.figure(figsize=(16, 8))
columns = 10
rows = 4
for i in range(0, columns * rows):
    fig.add_subplot(rows, columns, i+1)
    if i < 20:
        plt.imshow(img[c[i]], cmap='Greys_r')
        plt.title('Cancer')
        plt.xticks([])
        plt.yticks([])
    else:
        plt.imshow(img[s[i-20]], cmap='Greys_r')
        plt.title('Healthy Tissue')
        plt.xticks([])
        plt.yticks([])
plt.show()

# %% [markdown]
# ## 3. Perceptron Training

# %% [markdown]
# ### 3.1  Train and Test Sets creation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,
                                                    shuffle=True, random_state=0)

# %%
print("Training set")
print("X: ", X_train.shape)
print("Y: ", y_train.shape)
unique, counts = np.unique(y_train, return_counts=True)
print('Healthy Tissue:        ', counts[0],'\nCancer: ', counts[1],'\n')


print("Test set")
print("X: ", X_test.shape)
print("Y: ", y_test.shape)
unique, counts = np.unique(y_test, return_counts=True)
print('Healthy Tissue:         ', counts[0],'\nCancer: ', counts[1],'\n')
# Out:
# Training set
# X:  (3544, 67600)
# Y:  (3544,)
# Healthy Tissue:         1043
# Cancer:  2501
#
# Test set
# X:  (1519, 67600)
# Y:  (1519,)
# Healthy Tissue:          426
# Cancer:  1093

# %% [markdown]
# ### 3.2  Perceptron Training

# %%
model_p = Perceptron(max_iter=50, random_state=0, verbose=True)
model_p.fit(X_train,y_train)
# Out:
# -- Epoch 1
# Norm: 1123.26, NNZs: 67600, Bias: -39.000000, T: 3544, Avg. loss: 1641.286726
# Total training time: 0.50 seconds.
# -- Epoch 2
# Norm: 1709.08, NNZs: 67600, Bias: -56.000000, T: 7088, Avg. loss: 1415.700003
# Total training time: 1.01 seconds.
# -- Epoch 3
# Norm: 2155.80, NNZs: 67600, Bias: -69.000000, T: 10632, Avg. loss: 1231.936834
# Total training time: 1.58 seconds.
# -- Epoch 4
# Norm: 2616.13, NNZs: 67600, Bias: -76.000000, T: 14176, Avg. loss: 1124.851144
# Total training time: 2.12 seconds.
# -- Epoch 5
# Norm: 3021.59, NNZs: 67600, Bias: -75.000000, T: 17720, Avg. loss: 1133.721658
# Total training time: 2.70 seconds.
# -- Epoch 6
# Norm: 3379.11, NNZs: 67600, Bias: -74.000000, T: 21264, Avg. loss: 971.851823
# Total training time: 3.24 seconds.
# -- Epoch 7
# Norm: 3724.07, NNZs: 67600, Bias: -66.000000, T: 24808, Avg. loss: 937.594908
# Total training time: 3.81 seconds.
# -- Epoch 8
# Norm: 4026.70, NNZs: 67600, Bias: -68.000000, T: 28352, Avg. loss: 855.373414
# Total training time: 4.28 seconds.
# -- Epoch 9
# Norm: 4353.32, NNZs: 67600, Bias: -69.000000, T: 31896, Avg. loss: 866.263533
# Total training time: 4.73 seconds.
# -- Epoch 10
# Norm: 4660.13, NNZs: 67600, Bias: -65.000000, T: 35440, Avg. loss: 776.228995
# Total training time: 5.16 seconds.
# -- Epoch 11
# Norm: 4921.06, NNZs: 67600, Bias: -61.000000, T: 38984, Avg. loss: 678.473853
# Total training time: 5.59 seconds.
# -- Epoch 12
# Norm: 5171.96, NNZs: 67600, Bias: -60.000000, T: 42528, Avg. loss: 699.998242
# Total training time: 6.01 seconds.
# -- Epoch 13
# Norm: 5430.28, NNZs: 67600, Bias: -63.000000, T: 46072, Avg. loss: 702.381738
# Total training time: 6.43 seconds.
# -- Epoch 14
# Norm: 5668.24, NNZs: 67600, Bias: -66.000000, T: 49616, Avg. loss: 671.321657
# Total training time: 6.86 seconds.
# -- Epoch 15
# Norm: 5874.92, NNZs: 67600, Bias: -60.000000, T: 53160, Avg. loss: 616.342931
# Total training time: 7.27 seconds.
# -- Epoch 16
# Norm: 6076.95, NNZs: 67600, Bias: -61.000000, T: 56704, Avg. loss: 594.252122
# Total training time: 7.69 seconds.
# -- Epoch 17
# Norm: 6269.64, NNZs: 67600, Bias: -60.000000, T: 60248, Avg. loss: 564.383660
# Total training time: 8.11 seconds.
# -- Epoch 18
# Norm: 6476.34, NNZs: 67600, Bias: -60.000000, T: 63792, Avg. loss: 565.665024
# Total training time: 8.52 seconds.
# -- Epoch 19
# Norm: 6689.34, NNZs: 67600, Bias: -58.000000, T: 67336, Avg. loss: 524.297755
# Total training time: 8.94 seconds.
# -- Epoch 20
# Norm: 6862.68, NNZs: 67600, Bias: -48.000000, T: 70880, Avg. loss: 511.356194
# Total training time: 9.35 seconds.
# -- Epoch 21
# Norm: 7028.38, NNZs: 67600, Bias: -49.000000, T: 74424, Avg. loss: 474.784911
# Total training time: 9.76 seconds.
# -- Epoch 22
# Norm: 7204.30, NNZs: 67600, Bias: -48.000000, T: 77968, Avg. loss: 476.401283
# Total training time: 10.18 seconds.
# -- Epoch 23
# Norm: 7387.32, NNZs: 67600, Bias: -60.000000, T: 81512, Avg. loss: 478.475253
# Total training time: 10.60 seconds.
# -- Epoch 24
# Norm: 7540.80, NNZs: 67600, Bias: -60.000000, T: 85056, Avg. loss: 424.364124
# Total training time: 11.00 seconds.
# -- Epoch 25
# Norm: 7695.07, NNZs: 67600, Bias: -57.000000, T: 88600, Avg. loss: 397.421738
# Total training time: 11.40 seconds.
# -- Epoch 26
# Norm: 7845.61, NNZs: 67600, Bias: -49.000000, T: 92144, Avg. loss: 416.331109
# Total training time: 11.81 seconds.
# -- Epoch 27
# Norm: 8000.78, NNZs: 67600, Bias: -46.000000, T: 95688, Avg. loss: 412.591219
# Total training time: 12.22 seconds.
# -- Epoch 28
# Norm: 8155.36, NNZs: 67600, Bias: -45.000000, T: 99232, Avg. loss: 428.564681
# Total training time: 12.62 seconds.
# -- Epoch 29
# Norm: 8286.79, NNZs: 67600, Bias: -46.000000, T: 102776, Avg. loss: 365.973572
# Total training time: 13.03 seconds.
# -- Epoch 30
# Norm: 8417.99, NNZs: 67600, Bias: -47.000000, T: 106320, Avg. loss: 365.643387
# Total training time: 13.43 seconds.
# -- Epoch 31
# Norm: 8539.75, NNZs: 67600, Bias: -45.000000, T: 109864, Avg. loss: 324.497018
# Total training time: 13.83 seconds.
# -- Epoch 32
# Norm: 8653.12, NNZs: 67600, Bias: -39.000000, T: 113408, Avg. loss: 352.922933
# Total training time: 14.27 seconds.
# -- Epoch 33
# Norm: 8785.61, NNZs: 67600, Bias: -40.000000, T: 116952, Avg. loss: 366.305244
# Total training time: 14.74 seconds.
# -- Epoch 34
# Norm: 8906.23, NNZs: 67600, Bias: -39.000000, T: 120496, Avg. loss: 321.524374
# Total training time: 15.21 seconds.
# -- Epoch 35
# Norm: 9025.11, NNZs: 67600, Bias: -46.000000, T: 124040, Avg. loss: 302.449620
# Total training time: 15.72 seconds.
# -- Epoch 36
# Norm: 9138.24, NNZs: 67600, Bias: -41.000000, T: 127584, Avg. loss: 336.517278
# Total training time: 16.19 seconds.
# -- Epoch 37
# Norm: 9256.34, NNZs: 67600, Bias: -45.000000, T: 131128, Avg. loss: 308.302559
# Total training time: 16.66 seconds.
# -- Epoch 38
# Norm: 9363.62, NNZs: 67600, Bias: -45.000000, T: 134672, Avg. loss: 293.436983
# Total training time: 17.13 seconds.
# -- Epoch 39
# Norm: 9457.47, NNZs: 67600, Bias: -42.000000, T: 138216, Avg. loss: 256.112092
# Total training time: 17.55 seconds.
# -- Epoch 40
# Norm: 9572.63, NNZs: 67600, Bias: -43.000000, T: 141760, Avg. loss: 287.843137
# Total training time: 17.94 seconds.
# -- Epoch 41
# Norm: 9681.44, NNZs: 67600, Bias: -46.000000, T: 145304, Avg. loss: 285.325545
# Total training time: 18.34 seconds.
# -- Epoch 42
# Norm: 9768.06, NNZs: 67600, Bias: -42.000000, T: 148848, Avg. loss: 273.327549
# Total training time: 18.72 seconds.
# -- Epoch 43
# Norm: 9858.35, NNZs: 67600, Bias: -40.000000, T: 152392, Avg. loss: 280.426231
# Total training time: 19.12 seconds.
# -- Epoch 44
# Norm: 9960.65, NNZs: 67600, Bias: -42.000000, T: 155936, Avg. loss: 269.664988
# Total training time: 19.51 seconds.
# Convergence after 44 epochs took 19.51 seconds
# Perceptron(max_iter=50, verbose=True)

# %%
print("Train Set Accuracy: %.2f%%" % (model_p.score(X_train, y_train)*100.0))
print("Test Set Accuracy: %.2f%%" % (model_p.score(X_test, y_test)*100.0))
# Out:
# Train Set Accuracy: 95.49%
# Test Set Accuracy: 90.19%

# %%
y_pred = model_p.predict(X_test)

# %%
print("Accuracy: %.2f%%" % (accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 90.19%

# %%
matrix_confusion(y_test, y_pred)

# %% [markdown]
# ## 4. Percetron Training with alpha and penalty

# %%
model_mp = Perceptron(max_iter=1000, random_state=0, verbose=False, alpha=0.0001)
model_mp.fit(X_train,y_train)

print("Train Set Accuracy: %.2f%%" % (model_mp.score(X_train, y_train)*100.0))
print("Test Set Accuracy: %.2f%%" % (model_mp.score(X_test, y_test)*100.0))
# Out:
# Train Set Accuracy: 95.49%
# Test Set Accuracy: 90.19%

# %%
y_pred = model_mp.predict(X_test)

# %%
print("Accuracy: %.2f%%" % (accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 90.19%

# %%
matrix_confusion(y_test, y_pred)

# %%
model_mp1 = Perceptron(max_iter=1000,  random_state=0, verbose=False, alpha=0.000001, penalty='l2') # Adds L2 penalty
model_mp1.fit(X_train,y_train)

print("Train Set Accuracy: %.2f%%" % (model_mp1.score(X_train, y_train)*100.0))
print("Test Set Accuracy: %.2f%%" % (model_mp1.score(X_test, y_test)*100.0))
# Out:
# Train Set Accuracy: 98.59%
# Test Set Accuracy: 92.03%

# %%
y_pred = model_mp1.predict(X_test)  #pasa cada una de las imágenes de X_test por el modelo

# %%
print("Accuracy: %.2f%%" % (accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 92.03%

# %%
matrix_confusion(y_test, y_pred)

# %% [markdown]
# ## 5. Quantum Machine Learning - QCNN Training

# %%
# !pip install qiskit==1.2.4 qiskit-aer==0.15.1 qiskit-machine-learning==0.7.2 torchviz torchsummary
# Out:
# Requirement already satisfied: qiskit==1.2.4 in /usr/local/lib/python3.12/dist-packages (1.2.4)
# Requirement already satisfied: qiskit-aer==0.15.1 in /usr/local/lib/python3.12/dist-packages (0.15.1)
# Requirement already satisfied: qiskit-machine-learning==0.7.2 in /usr/local/lib/python3.12/dist-packages (0.7.2)
# Requirement already satisfied: torchviz in /usr/local/lib/python3.12/dist-packages (0.0.3)
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.12/dist-packages (1.5.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (1.16.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (5.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (4.15.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in /usr/local/lib/python3.12/dist-packages (from qiskit==1.2.4) (0.13.0)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer==0.15.1) (5.9.5)
# Requirement already satisfied: qiskit-algorithms>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning==0.7.2) (0.4.0)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning==0.7.2) (1.6.1)
# Requirement already satisfied: fastdtw in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning==0.7.2) (0.3.4)
# Requirement already satisfied: setuptools>=40.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning==0.7.2) (75.2.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchviz) (2.8.0+cu126)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from torchviz) (0.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit==1.2.4) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->qiskit-machine-learning==0.7.2) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->qiskit-machine-learning==0.7.2) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit==1.2.4) (1.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.19.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torchviz) (3.0.2)

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-dev python3.10-venv -y
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --config python3
# !python3 -m pip install --upgrade pip setuptools wheel
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [80.2 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,942 kB]
# Hit:5 https://cli.github.com/packages stable InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,209 kB]
# Get:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,305 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:16 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [42.7 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,560 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,272 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,357 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,623 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,579 kB]
# Get:22 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,783 kB]
# Fetched 35.2 MB in 5s (7,063 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.10 is already the newest version (3.10.12-1~22.04.11).
# python3.10 set to manually installed.
# python3.10-dev is already the newest version (3.10.12-1~22.04.11).
# python3.10-dev set to manually installed.
# The following NEW packages will be installed:
#   python3-pip-whl python3-setuptools-whl python3.10-venv
# 0 upgraded, 3 newly installed, 0 to remove and 41 not upgraded.
# Need to get 2,478 kB of archives.
# After this operation, 2,748 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip-whl all 22.0.2+dfsg-1ubuntu0.6 [1,680 kB]
# Get:2 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy/main amd64 python3-setuptools-whl all 68.1.2-2~jammy3 [792 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3.10-venv amd64 3.10.12-1~22.04.11 [5,726 B]
# Fetched 2,478 kB in 3s (820 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python3-pip-whl.
# (Reading database ... 126371 files and directories currently installed.)
# Preparing to unpack .../python3-pip-whl_22.0.2+dfsg-1ubuntu0.6_all.deb ...
# Unpacking python3-pip-whl (22.0.2+dfsg-1ubuntu0.6) ...
# Selecting previously unselected package python3-setuptools-whl.
# Preparing to unpack .../python3-setuptools-whl_68.1.2-2~jammy3_all.deb ...
# Unpacking python3-setuptools-whl (68.1.2-2~jammy3) ...
# Selecting previously unselected package python3.10-venv.
# Preparing to unpack .../python3.10-venv_3.10.12-1~22.04.11_amd64.deb ...
# Unpacking python3.10-venv (3.10.12-1~22.04.11) ...
# Setting up python3-setuptools-whl (68.1.2-2~jammy3) ...
# Setting up python3-pip-whl (22.0.2+dfsg-1ubuntu0.6) ...
# Setting up python3.10-venv (3.10.12-1~22.04.11) ...
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.12   2         auto mode
#   1            /usr/bin/python3.10   1         manual mode
#   2            /usr/bin/python3.12   2         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 1
# update-alternatives: using /usr/bin/python3.10 to provide /usr/bin/python3 (python3) in manual mode
# /usr/bin/python3: No module named pip

# %%
# !sudo apt-get update
# !sudo apt-get install python3.10-distutils python3.10-venv -y
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.10
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,632 B in 1s (2,650 B/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3-distutils set to manually installed.
# python3.10-venv is already the newest version (3.10.12-1~22.04.11).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting setuptools
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 54.0 MB/s  0:00:00
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: wheel, setuptools, pip
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pip]
# Successfully installed pip-25.2 setuptools-80.9.0 wheel-0.45.1

# %%
# !python3.10 -m pip --version
# Out:
# pip 25.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !git clone https://github.com/chandanashiremath1208/AI-MINI-PROJECT-.git
# !cd AI-MINI-PROJECT-
# Out:
# Cloning into 'AI-MINI-PROJECT-'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 18 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 20.88 MiB | 11.16 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# !pip install scikit-image scikit-learn matplotlib seaborn pandas numpy
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pandas
#   Downloading pandas-2.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting numpy
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting scipy>=1.11.4 (from scikit-image)
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting networkx>=3.0 (from scikit-image)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting pillow>=10.1 (from scikit-image)
#   Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2025.5.10-py3-none-any.whl.metadata (31 kB)
# Collecting packaging>=21 (from scikit-image)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (109 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 135.8 MB/s  0:00:00
# Downloading scikit_learn-1.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 160.3 MB/s  0:00:00
# Downloading matplotlib-3.10.6-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 144.8 MB/s  0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading pandas-2.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 177.3 MB/s  0:00:00
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 181.0 MB/s  0:00:00
# Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 145.2 MB/s  0:00:00
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 90.8 MB/s  0:00:00
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 89.7 MB/s  0:00:00
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pillow-11.3.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 132.7 MB/s  0:00:00
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 44.0 MB/s  0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tifffile-2025.5.10-py3-none-any.whl (226 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, python-dateutil, pillow, packaging, numpy, networkx, kiwisolver, joblib, fonttools, cycler, tifffile, scipy, pandas, lazy-loader, imageio, contourpy, scikit-learn, scikit-image, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22/22 [seaborn]
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.59.2 imageio-2.37.0 joblib-1.5.2 kiwisolver-1.4.9 lazy-loader-0.4 matplotlib-3.10.6 networkx-3.4.2 numpy-2.2.6 packaging-25.0 pandas-2.3.2 pillow-11.3.0 python-dateutil-2.9.0.post0 pytz-2025.2 scikit-image-0.25.2 scikit-learn-1.7.1 scipy-1.15.3 seaborn-0.13.2 threadpoolctl-3.6.0 tifffile-2025.5.10 tzdata-2025.2

# %%
# !ls
# Out:
#  AI-MINI-PROJECT-      'CONNECT 4 GAME FINAL.-1.docx'
# 'AI PROJECT PPT.pptx'   VID-20240101-WA0021.mp4

# %%
# %cd AI-MINI-PROJECT-
# !ls
# Out:
# /content/AI-MINI-PROJECT-/AI-MINI-PROJECT-
# 'AI PROJECT PPT.pptx'  'CONNECT 4 GAME FINAL.-1.docx'   VID-20240101-WA0021.mp4

# %%
# !ls .ipynb_checkpoints
# Out:
# 'CancerClassifier Using HQCNN-1-checkpoint.ipynb'

# %%
# !cp .ipynb_checkpoints/"CancerClassifier Using HQCNN-1-checkpoint.ipynb" "./CancerClassifier_Using_HQCNN.ipynb"

# %%
# !pip uninstall -y qiskit qiskit-aer qiskit-machine-learning pennylane pennylane-qiskit

# %%
train_data = torchvision.datasets.ImageFolder('C:\\Users\\conte\\OneDrive\\Escritorio\\Colegio Bourbaki\\ML-AI-WA\\Perceptron\\Imagenes_Clasificadas_Random_Split\\Train', transform=transforms.Compose([transforms.ToTensor()]))
test_data = torchvision.datasets.ImageFolder('C:\\Users\\conte\\OneDrive\\Escritorio\\Colegio Bourbaki\\ML-AI-WA\\Perceptron\\Imagenes_Clasificadas_Random_Split\\Test', transform=transforms.Compose([transforms.ToTensor()]))

# %% [markdown]
# Input Tensor Dimension

# %%
train_data[0][0].shape
# Out:
# torch.Size([3, 260, 260])

# %%
train_loader = DataLoader(train_data, shuffle=True, batch_size=1)
test_loader = DataLoader(test_data, shuffle=True, batch_size=1)

# %% [markdown]
# ## Show Images

# %%
# False is no cancer (0) and True, yes (1)
print((train_loader.dataset.class_to_idx))
# Out:
# {'False': 0, 'True': 1}

# %%
n_samples_show = 6

data_iter = iter(train_loader)
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 10))

while n_samples_show > 0:
    images, targets = data_iter.__next__()

    axes[n_samples_show - 1].imshow(images[0, 0].numpy().squeeze(), cmap=plt.cm.rainbow)
    axes[n_samples_show - 1].set_xticks([])
    axes[n_samples_show - 1].set_yticks([])
    axes[n_samples_show - 1].set_title(f"Labeled: {targets[0].item()}")

    n_samples_show -= 1

# %%
qi = QuantumInstance(Aer.get_backend("aer_simulator_statevector"))

# %% [markdown]
# ### Quantum Neural Network Definition

# %%
def create_qnn():
    feature_map = ZZFeatureMap(2)
    ansatz = RealAmplitudes(2, reps=1)
    qnn = TwoLayerQNN(
        2,
        feature_map,
        ansatz,
        input_gradients=True,
        exp_val=AerPauliExpectation(),
        quantum_instance=qi,
    )
    return qnn

# %%
qnn = create_qnn()

# %% [markdown]
# #### Circuit Graph

# %%
qnn.circuit.draw(output='mpl')

# %% [markdown]
# #### ZZFeatureMap Graph / Second-order Pauli-Z evolution circuit.

# %%
qnn.feature_map.decompose().draw(output='mpl')

# %% [markdown]
# #### RealAmplitudes Graph / Real-Amplitudes 2-local circuit.

# %%
qnn.ansatz.decompose().draw(output='mpl')

# %% [markdown]
# ### Quantum Entaglement Check

# %% [markdown]
# There are CNOT gates in the circuits like ZZFeatureMap and RealAmplitudes, thus the QNN makes use of entanglement.<br>
# <br>
# Probably in 99% of cases there is entanglement but not always (e.g. if the inputs to CNOTs are in only |0> or |1>), thus at the end is parameter dependant

# %% [markdown]
# Let's check the circuit parameters:

# %%
qnn.circuit.parameters
# Out:
# ParameterView([ParameterVectorElement(x[0]), ParameterVectorElement(x[1]), ParameterVectorElement(θ[0]), ParameterVectorElement(θ[1]), ParameterVectorElement(θ[2]), ParameterVectorElement(θ[3])])

# %% [markdown]
# Let's generate parameters randomly:

# %%
params = np.random.uniform(-1, 1, len(qnn.circuit.parameters))
params
# Out:
# array([-0.59250565, -0.57766283,  0.61099097, -0.68353721, -0.39525827,
#        -0.22483577])

# %% [markdown]
# Let's bind parameters, get the Circuit Density Matrix and get the purity state of it:

# %%
rho_01 = DensityMatrix.from_instruction(qnn.circuit.bind_parameters(params))

# %%
plot_state_city(rho_01.data, title='Density Matrix', figsize=(12,6))

# %%
gamma_p = rho_01.purity()
display(rho_01.draw('latex', prefix='\\rho_p = '))
print("State purity: ", np.round(np.real(gamma_p), 3))
# Out:
# $$
# \rho_p =
# \begin{bmatrix}
# 0.1331 & 0.10791 - 0.20321i & 0.10447 - 0.04943i & 0.19869 - 0.09805i  \\
#  0.10791 + 0.20321i & 0.39773 & 0.16016 + 0.11943i & 0.31077 + 0.22384i  \\
#  0.10447 + 0.04943i & 0.16016 - 0.11943i & 0.10036 & 0.19236 - 0.00318i  \\
#  0.19869 + 0.09805i & 0.31077 - 0.22384i & 0.19236 + 0.00318i & 0.36881  \\
#  \end{bmatrix}
# $$
# State purity:  1.0

# %%
print(f'{entanglement_of_formation(rho_01):.4f}')
# Out:
# 0.2802

# %% [markdown]
# ### Pytorch Neural Net Definition

# %%
# Red Neuronal en Pytorch
class Net(Module):
    def __init__(self, qnn):
        super().__init__()
        self.conv1 = Conv2d(3, 128, kernel_size=5)
        self.conv2 = Conv2d(128, 128, kernel_size=3)
        self.dropout = Dropout2d()
        self.fc1 = Linear(508032, 128)
        self.fc2 = Linear(128, 2) # QNN binary input
        self.qnn = TorchConnector(qnn) # use TorchConnector to bind quantum node and classic convolutional layers
        self.fc3 = Linear(1, 1)  # Quantum Circuit Output

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = self.dropout(x)
        x = x.view(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = self.qnn(x)  # QNN in foward section
        x = self.fc3(x)
        return cat((x, 1 - x), -1)

model = Net(qnn)

# %% [markdown]
# ### GPU Model Activation

# %%
model = model.to('cuda')

# %% [markdown]
# ### Show Model

# %%
print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 128, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (dropout): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=508032, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=2, bias=True)
#   (qnn): TorchConnector()
#   (fc3): Linear(in_features=1, out_features=1, bias=True)
# )

# %%
summary(model, (3, 260, 260), batch_size=-1, device='cuda')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1        [-1, 128, 256, 256]           9,728
#             Conv2d-2        [-1, 128, 126, 126]         147,584
#          Dropout2d-3          [-1, 128, 63, 63]               0
#             Linear-4                  [-1, 128]      65,028,224
#             Linear-5                    [-1, 2]             258
#     TorchConnector-6                    [-1, 1]               4
#             Linear-7                    [-1, 1]               2
# ================================================================
# Total params: 65,185,800
# Trainable params: 65,185,800
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.77
# Forward/backward pass size (MB): 83.38
# Params size (MB): 248.66
# Estimated Total Size (MB): 332.82
# ----------------------------------------------------------------

# %%
# dummy_tensor = next(iter(train_loader))[0].to('cuda')
# make_dot(model(dummy_tensor), params=dict(list(model.named_parameters())), show_saved=True, show_attrs=True).render("rnn_torchviz", format="png")
#Image('https://raw.githubusercontent.com/contepablod/QCNNCancerClassifier/master/rnn_torchviz.png')
Image(r'C:\Users\conte\OneDrive\Escritorio\qiskit-fall-fest-peru-2022-main\qiskit-community-tutorials-master\qiskit-community-tutorials-master\drafts\rnn_torchviz.png', width=2000, height=2250)

# %% [markdown]
# ### Optimisation and Loss Function Definition, and finally training

# %%
optimizer = optim.Adam(model.parameters(), lr=0.00001)
loss_func = CrossEntropyLoss().to('cuda')


epochs = 50
model.train()

loss_list = []
total_accuracy = []

for epoch in range(epochs):
    correct = 0
    total_loss = []
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad(set_to_none=True)
        output = model(data.to('cuda'))  # Forward pass, Data to GPU
        loss = loss_func(output, target.to('cuda')) #Labels to GPU
        loss.backward()  # Backward pass
        optimizer.step()
        total_loss.append(loss.item())
        train_pred = output.argmax(dim=1, keepdim=True)
        correct += train_pred.eq(target.to('cuda').view_as(train_pred)).sum().item()
    loss_list.append(sum(total_loss) / len(total_loss))
    accuracy = 100 * correct / len(train_loader)
    total_accuracy.append(accuracy)
    print(f"Training [{100.0 * (epoch + 1) / epochs:.0f}%]\tLoss: {loss_list[-1]:.4f}\tAccuracy: {accuracy:.2f}%")
# Out:
# Training [2%]	Loss: 0.6158	Accuracy: 68.52%
# Training [4%]	Loss: 0.5503	Accuracy: 77.73%
# Training [6%]	Loss: 0.5232	Accuracy: 81.34%
# Training [8%]	Loss: 0.5083	Accuracy: 84.08%
# Training [10%]	Loss: 0.4688	Accuracy: 85.84%
# Training [12%]	Loss: 0.4375	Accuracy: 88.73%
# Training [14%]	Loss: 0.4055	Accuracy: 90.88%
# Training [16%]	Loss: 0.3808	Accuracy: 93.07%
# Training [18%]	Loss: 0.3613	Accuracy: 93.83%
# Training [20%]	Loss: 0.3408	Accuracy: 94.44%
# Training [22%]	Loss: 0.3255	Accuracy: 94.53%
# Training [24%]	Loss: 0.3108	Accuracy: 95.59%
# Training [26%]	Loss: 0.2964	Accuracy: 95.93%
# Training [28%]	Loss: 0.2775	Accuracy: 96.90%
# Training [30%]	Loss: 0.2647	Accuracy: 96.84%
# Training [32%]	Loss: 0.2480	Accuracy: 97.48%
# Training [34%]	Loss: 0.2389	Accuracy: 97.57%
# Training [36%]	Loss: 0.2232	Accuracy: 97.81%
# Training [38%]	Loss: 0.2109	Accuracy: 98.39%
# Training [40%]	Loss: 0.1980	Accuracy: 98.69%
# Training [42%]	Loss: 0.1890	Accuracy: 98.81%
# Training [44%]	Loss: 0.1817	Accuracy: 98.54%
# Training [46%]	Loss: 0.1675	Accuracy: 98.78%
# Training [48%]	Loss: 0.1600	Accuracy: 99.03%
# Training [50%]	Loss: 0.1508	Accuracy: 99.27%
# Training [52%]	Loss: 0.1443	Accuracy: 99.00%
# Training [54%]	Loss: 0.1346	Accuracy: 99.27%
# Training [56%]	Loss: 0.1270	Accuracy: 99.45%
# Training [58%]	Loss: 0.1198	Accuracy: 99.42%
# Training [60%]	Loss: 0.1136	Accuracy: 99.54%
# Training [62%]	Loss: 0.1054	Accuracy: 99.57%
# Training [64%]	Loss: 0.1024	Accuracy: 99.48%
# Training [66%]	Loss: 0.0957	Accuracy: 99.67%
# Training [68%]	Loss: 0.0884	Accuracy: 99.73%
# Training [70%]	Loss: 0.0830	Accuracy: 99.70%
# Training [72%]	Loss: 0.0777	Accuracy: 99.76%
# Training [74%]	Loss: 0.0759	Accuracy: 99.73%
# Training [76%]	Loss: 0.0693	Accuracy: 99.79%
# Training [78%]	Loss: 0.0695	Accuracy: 99.64%
# Training [80%]	Loss: 0.0606	Accuracy: 99.88%
# Training [82%]	Loss: 0.0563	Accuracy: 99.91%
# Training [84%]	Loss: 0.0545	Accuracy: 99.79%
# Training [86%]	Loss: 0.0500	Accuracy: 99.85%
# Training [88%]	Loss: 0.0499	Accuracy: 99.79%
# Training [90%]	Loss: 0.0465	Accuracy: 99.82%
# Training [92%]	Loss: 0.0410	Accuracy: 99.91%
# Training [94%]	Loss: 0.0416	Accuracy: 99.82%
# Training [96%]	Loss: 0.0346	Accuracy: 99.94%
# Training [98%]	Loss: 0.0345	Accuracy: 99.91%
# Training [100%]	Loss: 0.0345	Accuracy: 99.82%

# %% [markdown]
# ### Convergence Plot

# %%
fig, ax1 = plt.subplots()
ax1.plot(loss_list, 'g-')
ax2 = ax1.twinx()
ax2.plot(total_accuracy, 'b')
plt.title("Hybrid NN Training Convergence", color='red')
ax1.set_xlabel("Training Iterations")
ax1.set_ylabel("Cross Entropy Loss", color='g')
ax2.set_ylabel("Accuracy (%)", color='b')
plt.show()

# %% [markdown]
# ### Save Model

# %%
torch.save(model.state_dict(), "model.pt")

# %% [markdown]
# ### Load Model to prediction

# %%
qnn1 = create_qnn()
model1 = Net(qnn1)
model1.load_state_dict(torch.load("model.pt"))
model1= model1.to('cuda')

# %%
batch_size=1

model1.eval()
pred_targets = []
test_targets= []
with no_grad():

    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        output = model1(data.to('cuda'))
        if len(output.shape) == 1:
            output = output.reshape(1, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)
        pred_targets.append(pred.item())
        test_targets.append(target.item())
        correct += pred.eq(target.to('cuda').view_as(pred)).sum().item()

        loss = loss_func(output, target.to('cuda'))
        total_loss.append(loss.item())

    print(f"Performance on test data:\n\tLoss: {sum(total_loss) / len(total_loss):.4f}\n\tAccuracy: {100 * correct / len(test_loader) / batch_size:.2f}%")
# Out:
# Performance on test data:
# 	Loss: 0.0438
# 	Accuracy: 98.76%

# %% [markdown]
# ### Show predicted images

# %%
from PIL import Image

n_samples_show = 6
count = 0
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 3))

model1.eval()
with no_grad():
    for batch_idx, (data, target) in enumerate(test_loader):
        if count == n_samples_show:
            break
        output = model1(data.to('cuda')[0:1])
        if len(output.shape) == 1:
            output = output.reshape(3, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)

        axes[count].imshow(torchvision.transforms.ToPILImage(mode='RGB')(data[0].squeeze()), cmap=plt.cm.rainbow)

        axes[count].set_xticks([])
        axes[count].set_yticks([])
        axes[count].set_title("Predicted {}".format(pred.item()))

        count += 1

# %%
matrix_confusion(test_targets, pred_targets)

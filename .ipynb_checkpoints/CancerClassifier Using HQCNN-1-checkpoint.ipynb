# %% [markdown]
# <a href="https://colab.research.google.com/github/chandanashiremath1208/AI-MINI-PROJECT-/blob/main/.ipynb_checkpoints/CancerClassifier%20Using%20HQCNN-1-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Load required libraries

# %%
import os
import random

import numpy as np
import pandas as pd

from skimage import io

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.1 Required Functions

# %%
def matrix_confusion(yt, yp):
    data = {'Y_Real': yt,
            'Y_Prediccion': yp}

    df = pd.DataFrame(data, columns=['Y_Real','Y_Prediccion'])
    confusion_matrix = pd.crosstab(df['Y_Real'], df['Y_Prediccion'], rownames=['Real'], colnames=['Predicted'])
    sns.heatmap(confusion_matrix, annot=True, fmt='g')

    plt.show()

# %% [markdown]
# ## 2. Read Data

# %% [markdown]
# ### 2.1 Read Labels (Y)

# %%
data = pd.read_csv("https://raw.githubusercontent.com/AnIsAsPe/ClassificadorCancerEsofago/master/Datos/ClasesImagenes.csv", usecols=[1,2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5063 entries, 0 to 5062
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   image_filename  5063 non-null   object
#  1   class_number    5063 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 79.2+ KB

# %%
data['class_number'].value_counts(sort=False)
# Out:
# class_number
# 0    1469
# 1    3594
# Name: count, dtype: int64

# %% [markdown]
# Class 0 belongs to Healthy Tissue y Class 1 to Cancerous Tissue

# %%
Y = data['class_number']

# %% [markdown]
# ### 2.2 Read Images (X)

# %%
data['image_filename']
# Out:
# 0          im_4_0.png
# 1         im_21_0.png
# 2          im_9_0.png
# 3          im_8_0.png
# 4         im_15_0.png
#             ...
# 5058    im_114_55.png
# 5059      im_7_55.png
# 5060     im_52_55.png
# 5061     im_10_55.png
# 5062    im_111_55.png
# Name: image_filename, Length: 5063, dtype: object

# %% [markdown]
# ## Images can be dowloaded from:
# https://github.com/contepablod/QCNNCancerClassifier/tree/master/CarpetaImagenes
#
# We read them from local disk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'AI MINI PROJECT '
# 'BREAST CANCER DIAGNOSIS'
# 'Breast Cancer Diagnosis Architecture.drawio'
# 'breast_cancer_diagnosis_code (1).ipynb'
#  breast_cancer_diagnosis_code.ipynb
# 'Breast Cancer Diagnosis Report.docx'
#  Cancer-Image-Classifier-Using-HQCNN-main
# 'CAPESTONE PROJECT ARCHTECTURE DIAGRAM.drawio'
# 'CAPESTONE PROJECT ARCHTECTURE DIAGRAM.drawio.png'
# 'Chandana S Hiremath aadhar card .pdf'
# 'CHANDANA S HIREMATH.pdf'
# 'CHANDANA S HIREMATH RESUME 17TH JULY 2025.pdf'
#  Classroom
# 'Colab Notebooks'
# 'CSH passport size photo .pdf'
#  Dentalxrays
#  ENG22AM0172_C1.pdf.pdf
# 'ENG22AM0172 PEC PPT EXPLANATION.pptx'
# 'ENG22AM0172 PEC PPT.pptx'
# 'eng skit (The Time Travel).mp4'
# 'ER DIAGRAM FINAL.drawio'
# 'ER IDAGRAM FOR BLOOD BANK MANAGEMENT SYSTEM.drawio'
# 'INTRODUCTION VIDEO (1).mp4'
# 'MINOR PROJECT ARCHITECTURE.drawio'
# 'Minor Project Report Content(4).pdf'
# 'skit final.mp4'
# 'SPECIAL TOPIC FLOW CHART'
#  VID20250718130322.mp4

# %%
# !ls "/content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main"
# Out:
# 'Image Cancer Classifier Using HQCNN.ipynb'
#  Imagenes_Clasificadas_Random_Split
#  Images
#  imagesubset.ipynb
# 'main code part CancerClassifier Using HQCNN-1.ipynb'
#  README.md

# %%
path = "/content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Images/"

# %%
import os
from skimage.io import imread
from skimage.transform import resize
from tqdm import tqdm

path = "/content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Images"

img = []
for fname in tqdm(data['image_filename']):
    image = imread(os.path.join(path, fname), as_gray=True)
    image = resize(image, (260, 260))   # resize to match your next step
    img.append(image)
# Out:
# 100%|██████████| 5063/5063 [1:01:21<00:00,  1.38it/s]

# %%
import numpy as np
img = np.array(img)
print(img.shape)  # should be (5063, 260, 260)
# Out:
# (5063, 260, 260)

# %% [markdown]
# - Dimension 0: 260 up-to-down pixels rows
# - Dimension 1: 260 left-to-right pixel columns

# %% [markdown]
# ####  Images to vectors

# %%
img.shape
# Out:
# (5063, 260, 260)

# %%
img[0].shape
# Out:
# (260, 260)

# %%
IMG = np.stack(img, axis=0)
IMG.shape
# Out:
# (5063, 260, 260)

# %% [markdown]
# Then flatten the 2D matrix (260x260 pixels) of each image, to obtain one vector per image.

# %%
X = IMG.reshape(5063, -1) # se puede poner 67600 en vez de -1
X.shape
# Out:
# (5063, 67600)

# %% [markdown]
# ##### Image Visualizer

# %%
byClass = data.groupby('class_number')

n = 20
c = random.sample(byClass.get_group(1).index.tolist(), n)
s = random.sample(byClass.get_group(0).index.tolist(), n)


fig = plt.figure(figsize=(16, 8))
columns = 10
rows = 4
for i in range(0, columns * rows):
    fig.add_subplot(rows, columns, i+1)
    if i < 20:
        plt.imshow(img[c[i]], cmap='Greys_r')
        plt.title('Cancer')
        plt.xticks([])
        plt.yticks([])
    else:
        plt.imshow(img[s[i-20]], cmap='Greys_r')
        plt.title('Healthy Tissue')
        plt.xticks([])
        plt.yticks([])
plt.show()

# %% [markdown]
# ## 3. Perceptron Training

# %% [markdown]
# ### 3.1  Train and Test Sets creation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,
                                                    shuffle=True, random_state=0)

# %%
print("Training set")
print("X: ", X_train.shape)
print("Y: ", y_train.shape)
unique, counts = np.unique(y_train, return_counts=True)
print('Healthy Tissue:        ', counts[0],'\nCancer: ', counts[1],'\n')


print("Test set")
print("X: ", X_test.shape)
print("Y: ", y_test.shape)
unique, counts = np.unique(y_test, return_counts=True)
print('Healthy Tissue:         ', counts[0],'\nCancer: ', counts[1],'\n')
# Out:
# Training set
# X:  (3544, 67600)
# Y:  (3544,)
# Healthy Tissue:         1043
# Cancer:  2501
#
# Test set
# X:  (1519, 67600)
# Y:  (1519,)
# Healthy Tissue:          426
# Cancer:  1093

# %% [markdown]
# ### 3.2  Perceptron Training

# %%
model_p = Perceptron(max_iter=50, random_state=0, verbose=True)
model_p.fit(X_train,y_train)
# Out:
# -- Epoch 1
# Norm: 1123.26, NNZs: 67600, Bias: -39.000000, T: 3544, Avg. loss: 1641.286726
# Total training time: 0.54 seconds.
# -- Epoch 2
# Norm: 1709.08, NNZs: 67600, Bias: -56.000000, T: 7088, Avg. loss: 1415.700003
# Total training time: 1.03 seconds.
# -- Epoch 3
# Norm: 2155.80, NNZs: 67600, Bias: -69.000000, T: 10632, Avg. loss: 1231.936834
# Total training time: 1.49 seconds.
# -- Epoch 4
# Norm: 2616.13, NNZs: 67600, Bias: -76.000000, T: 14176, Avg. loss: 1124.851144
# Total training time: 1.96 seconds.
# -- Epoch 5
# Norm: 3021.59, NNZs: 67600, Bias: -75.000000, T: 17720, Avg. loss: 1133.721658
# Total training time: 2.42 seconds.
# -- Epoch 6
# Norm: 3379.11, NNZs: 67600, Bias: -74.000000, T: 21264, Avg. loss: 971.851823
# Total training time: 2.87 seconds.
# -- Epoch 7
# Norm: 3724.07, NNZs: 67600, Bias: -66.000000, T: 24808, Avg. loss: 937.594908
# Total training time: 3.31 seconds.
# -- Epoch 8
# Norm: 4026.70, NNZs: 67600, Bias: -68.000000, T: 28352, Avg. loss: 855.373414
# Total training time: 3.75 seconds.
# -- Epoch 9
# Norm: 4353.32, NNZs: 67600, Bias: -69.000000, T: 31896, Avg. loss: 866.263533
# Total training time: 4.18 seconds.
# -- Epoch 10
# Norm: 4660.13, NNZs: 67600, Bias: -65.000000, T: 35440, Avg. loss: 776.228995
# Total training time: 4.62 seconds.
# -- Epoch 11
# Norm: 4921.06, NNZs: 67600, Bias: -61.000000, T: 38984, Avg. loss: 678.473853
# Total training time: 5.04 seconds.
# -- Epoch 12
# Norm: 5171.96, NNZs: 67600, Bias: -60.000000, T: 42528, Avg. loss: 699.998242
# Total training time: 5.47 seconds.
# -- Epoch 13
# Norm: 5430.28, NNZs: 67600, Bias: -63.000000, T: 46072, Avg. loss: 702.381738
# Total training time: 5.89 seconds.
# -- Epoch 14
# Norm: 5668.24, NNZs: 67600, Bias: -66.000000, T: 49616, Avg. loss: 671.321657
# Total training time: 6.31 seconds.
# -- Epoch 15
# Norm: 5874.92, NNZs: 67600, Bias: -60.000000, T: 53160, Avg. loss: 616.342931
# Total training time: 6.73 seconds.
# -- Epoch 16
# Norm: 6076.95, NNZs: 67600, Bias: -61.000000, T: 56704, Avg. loss: 594.252122
# Total training time: 7.15 seconds.
# -- Epoch 17
# Norm: 6269.64, NNZs: 67600, Bias: -60.000000, T: 60248, Avg. loss: 564.383660
# Total training time: 7.57 seconds.
# -- Epoch 18
# Norm: 6476.34, NNZs: 67600, Bias: -60.000000, T: 63792, Avg. loss: 565.665024
# Total training time: 7.98 seconds.
# -- Epoch 19
# Norm: 6689.34, NNZs: 67600, Bias: -58.000000, T: 67336, Avg. loss: 524.297755
# Total training time: 8.44 seconds.
# -- Epoch 20
# Norm: 6862.68, NNZs: 67600, Bias: -48.000000, T: 70880, Avg. loss: 511.356194
# Total training time: 8.94 seconds.
# -- Epoch 21
# Norm: 7028.38, NNZs: 67600, Bias: -49.000000, T: 74424, Avg. loss: 474.784911
# Total training time: 9.42 seconds.
# -- Epoch 22
# Norm: 7204.30, NNZs: 67600, Bias: -48.000000, T: 77968, Avg. loss: 476.401283
# Total training time: 9.93 seconds.
# -- Epoch 23
# Norm: 7387.32, NNZs: 67600, Bias: -60.000000, T: 81512, Avg. loss: 478.475253
# Total training time: 10.42 seconds.
# -- Epoch 24
# Norm: 7540.80, NNZs: 67600, Bias: -60.000000, T: 85056, Avg. loss: 424.364124
# Total training time: 10.93 seconds.
# -- Epoch 25
# Norm: 7695.07, NNZs: 67600, Bias: -57.000000, T: 88600, Avg. loss: 397.421738
# Total training time: 11.42 seconds.
# -- Epoch 26
# Norm: 7845.61, NNZs: 67600, Bias: -49.000000, T: 92144, Avg. loss: 416.331109
# Total training time: 11.86 seconds.
# -- Epoch 27
# Norm: 8000.78, NNZs: 67600, Bias: -46.000000, T: 95688, Avg. loss: 412.591219
# Total training time: 12.27 seconds.
# -- Epoch 28
# Norm: 8155.36, NNZs: 67600, Bias: -45.000000, T: 99232, Avg. loss: 428.564681
# Total training time: 12.67 seconds.
# -- Epoch 29
# Norm: 8286.79, NNZs: 67600, Bias: -46.000000, T: 102776, Avg. loss: 365.973572
# Total training time: 13.08 seconds.
# -- Epoch 30
# Norm: 8417.99, NNZs: 67600, Bias: -47.000000, T: 106320, Avg. loss: 365.643387
# Total training time: 13.48 seconds.
# -- Epoch 31
# Norm: 8539.75, NNZs: 67600, Bias: -45.000000, T: 109864, Avg. loss: 324.497018
# Total training time: 13.94 seconds.
# -- Epoch 32
# Norm: 8653.12, NNZs: 67600, Bias: -39.000000, T: 113408, Avg. loss: 352.922933
# Total training time: 14.39 seconds.
# -- Epoch 33
# Norm: 8785.61, NNZs: 67600, Bias: -40.000000, T: 116952, Avg. loss: 366.305244
# Total training time: 14.80 seconds.
# -- Epoch 34
# Norm: 8906.23, NNZs: 67600, Bias: -39.000000, T: 120496, Avg. loss: 321.524374
# Total training time: 15.21 seconds.
# -- Epoch 35
# Norm: 9025.11, NNZs: 67600, Bias: -46.000000, T: 124040, Avg. loss: 302.449620
# Total training time: 15.61 seconds.
# -- Epoch 36
# Norm: 9138.24, NNZs: 67600, Bias: -41.000000, T: 127584, Avg. loss: 336.517278
# Total training time: 16.02 seconds.
# -- Epoch 37
# Norm: 9256.34, NNZs: 67600, Bias: -45.000000, T: 131128, Avg. loss: 308.302559
# Total training time: 16.42 seconds.
# -- Epoch 38
# Norm: 9363.62, NNZs: 67600, Bias: -45.000000, T: 134672, Avg. loss: 293.436983
# Total training time: 16.82 seconds.
# -- Epoch 39
# Norm: 9457.47, NNZs: 67600, Bias: -42.000000, T: 138216, Avg. loss: 256.112092
# Total training time: 17.22 seconds.
# -- Epoch 40
# Norm: 9572.63, NNZs: 67600, Bias: -43.000000, T: 141760, Avg. loss: 287.843137
# Total training time: 17.62 seconds.
# -- Epoch 41
# Norm: 9681.44, NNZs: 67600, Bias: -46.000000, T: 145304, Avg. loss: 285.325545
# Total training time: 18.02 seconds.
# -- Epoch 42
# Norm: 9768.06, NNZs: 67600, Bias: -42.000000, T: 148848, Avg. loss: 273.327549
# Total training time: 18.41 seconds.
# -- Epoch 43
# Norm: 9858.35, NNZs: 67600, Bias: -40.000000, T: 152392, Avg. loss: 280.426231
# Total training time: 18.80 seconds.
# -- Epoch 44
# Norm: 9960.65, NNZs: 67600, Bias: -42.000000, T: 155936, Avg. loss: 269.664988
# Total training time: 19.20 seconds.
# Convergence after 44 epochs took 19.20 seconds
# Perceptron(max_iter=50, verbose=True)

# %%
print("Train Set Accuracy: %.2f%%" % (model_p.score(X_train, y_train)*100.0))
print("Test Set Accuracy: %.2f%%" % (model_p.score(X_test, y_test)*100.0))
# Out:
# Train Set Accuracy: 95.49%
# Test Set Accuracy: 90.19%

# %%
y_pred = model_p.predict(X_test)

# %%
print("Accuracy: %.2f%%" % (accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 90.19%

# %%
matrix_confusion(y_test, y_pred)

# %% [markdown]
# ## 4. Percetron Training with alpha and penalty

# %%
model_mp = Perceptron(max_iter=1000, random_state=0, verbose=False, alpha=0.0001)
model_mp.fit(X_train,y_train)

print("Train Set Accuracy: %.2f%%" % (model_mp.score(X_train, y_train)*100.0))
print("Test Set Accuracy: %.2f%%" % (model_mp.score(X_test, y_test)*100.0))
# Out:
# Train Set Accuracy: 95.49%
# Test Set Accuracy: 90.19%

# %%
y_pred = model_mp.predict(X_test)

# %%
print("Accuracy: %.2f%%" % (accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 90.19%

# %%
matrix_confusion(y_test, y_pred)

# %%
model_mp1 = Perceptron(max_iter=1000,  random_state=0, verbose=False, alpha=0.000001, penalty='l2') # Adds L2 penalty
model_mp1.fit(X_train,y_train)

print("Train Set Accuracy: %.2f%%" % (model_mp1.score(X_train, y_train)*100.0))
print("Test Set Accuracy: %.2f%%" % (model_mp1.score(X_test, y_test)*100.0))
# Out:
# Train Set Accuracy: 98.59%
# Test Set Accuracy: 92.03%

# %%
y_pred = model_mp1.predict(X_test)  #pasa cada una de las imágenes de X_test por el modelo

# %%
print("Accuracy: %.2f%%" % (accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 92.03%

# %%
matrix_confusion(y_test, y_pred)

# %% [markdown]
# ## 5. Quantum Machine Learning - QCNN Training

# %%
# !pip install torchviz
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.3-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from torchviz) (2.8.0+cu126)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from torchviz) (0.21)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->torchviz) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->torchviz) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->torchviz) (3.0.2)
# Downloading torchviz-0.0.3-py3-none-any.whl (5.7 kB)
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.3

# %%
# !pip install qiskit
# !pip install qiskit-aer
# !pip install qiskit-machine-learning
# !pip install torch torchvision torchaudio
# Out:
# Collecting qiskit
#   Downloading qiskit-2.1.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.5.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.15.0)
# Downloading qiskit-2.1.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 37.1 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 73.7 MB/s eta 0:00:00
# Downloading stevedore-5.5.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.6 MB/s eta 0:00:00
# Installing collected packages: stevedore, rustworkx, qiskit
# Successfully installed qiskit-2.1.2 rustworkx-0.17.1 stevedore-5.5.0
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.1.2)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (1.16.1)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (5.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-aer) (4.15.0)
# Downloading qiskit_aer-0.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 63.8 MB/s eta 0:00:00
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.17.1
# Collecting qiskit-machine-learning
#   Downloading qiskit_machine_learning-0.8.3-py3-none-any.whl.metadata (13 kB)
# Collecting qiskit<2.0,>=1.0 (from qiskit-machine-learning)
#   Downloading qiskit-1.4.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (2.0.2)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (1.16.1)
# Requirement already satisfied: scikit-learn>=1.2 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (1.6.1)
# Requirement already satisfied: setuptools>=40.1 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (75.2.0)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-machine-learning) (0.3.8)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit<2.0,>=1.0->qiskit-machine-learning) (0.17.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit<2.0,>=1.0->qiskit-machine-learning) (1.13.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit<2.0,>=1.0->qiskit-machine-learning) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit<2.0,>=1.0->qiskit-machine-learning) (5.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit<2.0,>=1.0->qiskit-machine-learning) (4.15.0)
# Collecting symengine<0.14,>=0.11 (from qiskit<2.0,>=1.0->qiskit-machine-learning)
#   Downloading symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2->qiskit-machine-learning) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2->qiskit-machine-learning) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit<2.0,>=1.0->qiskit-machine-learning) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit<2.0,>=1.0->qiskit-machine-learning) (1.3.0)
# Downloading qiskit_machine_learning-0.8.3-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 21.7 MB/s eta 0:00:00
# Downloading qiskit-1.4.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 85.8 MB/s eta 0:00:00
# Downloading symengine-0.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 2.4 MB/s eta 0:00:00
# Installing collected packages: symengine, qiskit, qiskit-machine-learning
#   Attempting uninstall: qiskit
#     Found existing installation: qiskit 2.1.2
#     Uninstalling qiskit-2.1.2:
#       Successfully uninstalled qiskit-2.1.2
# Successfully installed qiskit-1.4.4 qiskit-machine-learning-0.8.3 symengine-0.13.0
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.2)

# %%
import torch, torchvision, torch.utils
from torch import Tensor
from torch import cat
from torch.autograd.grad_mode import no_grad
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.optim as optim
from torch.nn import (
    Module,
    Conv2d,
    Linear,
    Dropout2d,
    NLLLoss, BCELoss, CrossEntropyLoss, MSELoss,
    MaxPool2d,
    Flatten,
    Sequential,
    ReLU,
)
import torch.nn.functional as F
from torchviz import make_dot
from torchsummary import summary

# Qiskit
from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector
from qiskit.primitives import Estimator
from qiskit_aer import Aer

# Note: You can remove the deprecated imports for Opflow, DensityMatrix, entanglement_of_formation, and plot_state_city unless your code specifically uses them later.
# from qiskit.opflow import AerPauliExpectation
# from qiskit.quantum_info import DensityMatrix, entanglement_of_formation
# from qiskit.visualization import plot_state_city

# %%
import os
for root, dirs, files in os.walk('/content/drive'):
  print(root)
# Out:
# /content/drive
# /content/drive/.shortcut-targets-by-id
# /content/drive/MyDrive
# /content/drive/MyDrive/Classroom
# /content/drive/MyDrive/Classroom/LA-DE A2
# /content/drive/MyDrive/Classroom/CPPS A2
# /content/drive/MyDrive/Classroom/I SEM A2
# /content/drive/MyDrive/Classroom/Ist Semester A2 2023 A2
# /content/drive/MyDrive/Classroom/A2 : Engineering Physics (2023) A2
# /content/drive/MyDrive/Classroom/B. Tech (A2-1) A2-1
# /content/drive/MyDrive/Classroom/II SEM A2
# /content/drive/MyDrive/Classroom/B. Tech (A2-2) A2-2
# /content/drive/MyDrive/Classroom/III SEM - AI&ML - DATA STRUCTURES A,B,C
# /content/drive/MyDrive/Classroom/TNT 2023-24 (3rd Sem ) CSE(D, I) , DS, AIML(C)
# /content/drive/MyDrive/Classroom/AI&ML DS LAB-SECTION-A
# /content/drive/MyDrive/Classroom/AI&ml DS LAB SECTION-C
# /content/drive/MyDrive/Classroom/AI & ML - 4th Sem Linux-Programming a,b,c
# /content/drive/MyDrive/Classroom/PEC- DATA SCIENCE A,B AND C
# /content/drive/MyDrive/Colab Notebooks
# /content/drive/MyDrive/AI MINI PROJECT
# /content/drive/MyDrive/BREAST CANCER DIAGNOSIS
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Test
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Test/True
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Test/False
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Train
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Train/True
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Train/False
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/.ipynb_checkpoints
# /content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Images
# /content/drive/.Trash-0
# /content/drive/.Trash-0/files
# /content/drive/.Trash-0/info
# /content/drive/.Encrypted
# /content/drive/.Encrypted/.shortcut-targets-by-id
# /content/drive/.Encrypted/.shortcut-targets-by-id/19YXjjy4qWEfJs0t4sLUqldxrYmOiKWLS
# /content/drive/.Encrypted/MyDrive
# /content/drive/.Encrypted/MyDrive/Classroom
# /content/drive/.Encrypted/MyDrive/Classroom/LA-DE A2
# /content/drive/.Encrypted/MyDrive/Classroom/CPPS A2
# /content/drive/.Encrypted/MyDrive/Classroom/I SEM A2
# /content/drive/.Encrypted/MyDrive/Classroom/Ist Semester A2 2023 A2
# /content/drive/.Encrypted/MyDrive/Classroom/A2 : Engineering Physics (2023) A2
# /content/drive/.Encrypted/MyDrive/Classroom/B. Tech (A2-1) A2-1
# /content/drive/.Encrypted/MyDrive/Classroom/II SEM A2
# /content/drive/.Encrypted/MyDrive/Classroom/B. Tech (A2-2) A2-2
# /content/drive/.Encrypted/MyDrive/Classroom/III SEM - AI&ML - DATA STRUCTURES A,B,C
# /content/drive/.Encrypted/MyDrive/Classroom/TNT 2023-24 (3rd Sem ) CSE(D, I) , DS, AIML(C)
# /content/drive/.Encrypted/MyDrive/Classroom/AI&ML DS LAB-SECTION-A
# /content/drive/.Encrypted/MyDrive/Classroom/AI&ml DS LAB SECTION-C
# /content/drive/.Encrypted/MyDrive/Classroom/AI & ML - 4th Sem Linux-Programming a,b,c
# /content/drive/.Encrypted/MyDrive/Classroom/PEC- DATA SCIENCE A,B AND C
# /content/drive/.Encrypted/MyDrive/Colab Notebooks
# /content/drive/.Encrypted/MyDrive/AI MINI PROJECT
# /content/drive/.Encrypted/MyDrive/BREAST CANCER DIAGNOSIS
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Test
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Test/True
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Test/False
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Train
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Train/True
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Train/False
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/.ipynb_checkpoints
# /content/drive/.Encrypted/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Images

# %%
import torchvision.datasets as datasets
from torchvision import transforms

train_data = datasets.ImageFolder('/content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Train', transform=transforms.Compose([transforms.ToTensor()]))
test_data = datasets.ImageFolder('/content/drive/MyDrive/Cancer-Image-Classifier-Using-HQCNN-main/Imagenes_Clasificadas_Random_Split/Test', transform=transforms.Compose([transforms.ToTensor()]))

print("Train data loaded successfully!")
print("Test data loaded successfully!")
# Out:
# Train data loaded successfully!
# Test data loaded successfully!

# %% [markdown]
# Input Tensor Dimension

# %%
train_data[0][0].shape
# Out:
# torch.Size([3, 260, 260])

# %%
train_loader = DataLoader(train_data, shuffle=True, batch_size=1)
test_loader = DataLoader(test_data, shuffle=True, batch_size=1)

# %% [markdown]
# ## Show Images

# %%
# False is no cancer (0) and True, yes (1)
print((train_loader.dataset.class_to_idx))
# Out:
# {'False': 0, 'True': 1}

# %%
n_samples_show = 6

data_iter = iter(train_loader)
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 10))

while n_samples_show > 0:
    images, targets = data_iter.__next__()

    axes[n_samples_show - 1].imshow(images[0, 0].numpy().squeeze(), cmap=plt.cm.rainbow)
    axes[n_samples_show - 1].set_xticks([])
    axes[n_samples_show - 1].set_yticks([])
    axes[n_samples_show - 1].set_title(f"Labeled: {targets[0].item()}")

    n_samples_show -= 1

# %%
from qiskit_aer import Aer
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector
from qiskit.primitives import Estimator

# Step 1: Define the backend.
# The Estimator doesn't take the backend as an argument anymore.
backend = Aer.get_backend("aer_simulator")

# Step 2: Instantiate the Estimator.
# It is now initialized without any arguments.
estimator = Estimator()

# You will then connect this estimator to the quantum neural network.
# The `TorchConnector` is what handles the execution on the specified backend.

# Example of how to use it later:
# qnn = EstimatorQNN(circuit=your_circuit, estimator=estimator)
# model = TorchConnector(qnn, ... )
# Out:
# /tmp/ipython-input-3944691019.py:12: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   estimator = Estimator()

# %% [markdown]
# ### Quantum Neural Network Definition

# %%
# !pip install pylatexenc
# Out:
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=abb7c7fd9138eb3ed659770b46645433f7ab9c6eee52e6ff81365f7c7fef0589
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10

# %%
from qiskit.primitives import Estimator
from qiskit.circuit.library import ZZFeatureMap, RealAmplitudes
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit.circuit import Parameter

# The updated create_qnn function to return the components
def create_qnn():
    # Define a single parameter for the feature map
    feature_map = ZZFeatureMap(2, reps=1, entanglement='linear')

    # Define a single parameter for the ansatz
    ansatz = RealAmplitudes(2, reps=1)

    # Combine the feature map and ansatz into a single circuit
    qc = QuantumCircuit(2)
    qc.append(feature_map, [0, 1])
    qc.append(ansatz, [0, 1])

    # Instantiate the new Estimator primitive
    estimator = Estimator()

    # Create the EstimatorQNN
    qnn = EstimatorQNN(
        circuit=qc,
        estimator=estimator,
        input_params=feature_map.parameters,
        weight_params=ansatz.parameters
    )

    return qnn, feature_map, ansatz

# In a new cell, call the function and unpack the returned values
qnn, feature_map, ansatz = create_qnn()

# Now you can draw the feature map using the correct object
feature_map.decompose().draw(output='mpl')
# Out:
# /tmp/ipython-input-1026959756.py:20: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   estimator = Estimator()
# /tmp/ipython-input-1026959756.py:23: DeprecationWarning: V1 Primitives are deprecated as of qiskit-machine-learning 0.8.0 and will be removed no sooner than 4 months after the release date. Use V2 primitives for continued compatibility and support.
#   qnn = EstimatorQNN(

# %% [markdown]
# #### Circuit Graph

# %%
qnn, feature_map, ansatz = create_qnn()
# Out:
# /tmp/ipython-input-1026959756.py:20: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   estimator = Estimator()
# /tmp/ipython-input-1026959756.py:23: DeprecationWarning: V1 Primitives are deprecated as of qiskit-machine-learning 0.8.0 and will be removed no sooner than 4 months after the release date. Use V2 primitives for continued compatibility and support.
#   qnn = EstimatorQNN(

# %%
# !pip install pylatexenc
# Out:
# Requirement already satisfied: pylatexenc in /usr/local/lib/python3.12/dist-packages (2.10)

# %%
qnn.circuit.draw(output='mpl')

# %% [markdown]
# #### ZZFeatureMap Graph / Second-order Pauli-Z evolution circuit.

# %%
feature_map.decompose().draw(output='mpl')

# %% [markdown]
# #### RealAmplitudes Graph / Real-Amplitudes 2-local circuit.

# %%
ansatz.decompose().draw(output='mpl')

# %% [markdown]
# ### Quantum Entaglement Check

# %% [markdown]
# There are CNOT gates in the circuits like ZZFeatureMap and RealAmplitudes, thus the QNN makes use of entanglement.<br>
# <br>
# Probably in 99% of cases there is entanglement but not always (e.g. if the inputs to CNOTs are in only |0> or |1>), thus at the end is parameter dependant

# %% [markdown]
# Let's check the circuit parameters:

# %%
import numpy as np
qnn.circuit.parameters
# Out:
# ParameterView([ParameterVectorElement(x[0]), ParameterVectorElement(x[1]), ParameterVectorElement(θ[0]), ParameterVectorElement(θ[1]), ParameterVectorElement(θ[2]), ParameterVectorElement(θ[3])])

# %% [markdown]
# Let's generate parameters randomly:

# %%
# Create the QNN and get the parameters
qnn, feature_map, ansatz = create_qnn()
params = np.random.uniform(-1, 1, len(qnn.circuit.parameters))
# Out:
# /tmp/ipython-input-1026959756.py:20: DeprecationWarning: The class ``qiskit.primitives.estimator.Estimator`` is deprecated as of qiskit 1.2. It will be removed no earlier than 3 months after the release date. All implementations of the `BaseEstimatorV1` interface have been deprecated in favor of their V2 counterparts. The V2 alternative for the `Estimator` class is `StatevectorEstimator`.
#   estimator = Estimator()
# /tmp/ipython-input-1026959756.py:23: DeprecationWarning: V1 Primitives are deprecated as of qiskit-machine-learning 0.8.0 and will be removed no sooner than 4 months after the release date. Use V2 primitives for continued compatibility and support.
#   qnn = EstimatorQNN(

# %% [markdown]
# Let's bind parameters, get the Circuit Density Matrix and get the purity state of it:

# %%
# The EstimatorQNN handles the parameter binding internally when called.
# Here we'll manually get the output from the circuit.
from qiskit.quantum_info import Statevector

# Get the quantum state vector from the circuit
state_vector = Statevector(qnn.circuit.assign_parameters(params))

# You can then get the density matrix from the state vector if needed
rho_01 = state_vector.to_operator()

# %%
# !pip install qiskit[visualization]
# Out:
# Requirement already satisfied: qiskit[visualization] in /usr/local/lib/python3.12/dist-packages (1.4.4)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (1.16.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (0.3.8)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (5.5.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (4.15.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (0.13.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (3.10.0)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (3.0.4)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (11.3.0)
# Requirement already satisfied: pylatexenc>=1.4 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from qiskit[visualization]) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3->qiskit[visualization]) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit[visualization]) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn>=0.9.0->qiskit[visualization]) (2.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.3->qiskit[visualization]) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2025.2)

# %%
from qiskit.visualization import state_city
import matplotlib.pyplot as plt

# The old `rho_01.draw(output='mpl')` is not supported.
# Use `state_city` from `qiskit.visualization` instead.
fig = state_city(rho_01, title="Density Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-3219848614.py in <cell line: 0>()
# ----> 1 from qiskit.visualization import state_city
#       2 import matplotlib.pyplot as plt
#       3
#       4 # The old `rho_01.draw(output='mpl')` is not supported.
#       5 # Use `state_city` from `qiskit.visualization` instead.
#
# ImportError: cannot import name 'state_city' from 'qiskit.visualization' (/usr/local/lib/python3.12/dist-packages/qiskit/visualization/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
gamma_p = rho_01.purity()
display(rho_01.draw('latex', prefix='\\rho_p = '))
print("State purity: ", np.round(np.real(gamma_p), 3))

# %%
print(f'{entanglement_of_formation(rho_01):.4f}')

# %% [markdown]
# ### Pytorch Neural Net Definition

# %%
# Red Neuronal en Pytorch
class Net(Module):
    def __init__(self, qnn):
        super().__init__()
        self.conv1 = Conv2d(3, 128, kernel_size=5)
        self.conv2 = Conv2d(128, 128, kernel_size=3)
        self.dropout = Dropout2d()
        self.fc1 = Linear(508032, 128)
        self.fc2 = Linear(128, 2) # QNN binary input
        self.qnn = TorchConnector(qnn) # use TorchConnector to bind quantum node and classic convolutional layers
        self.fc3 = Linear(1, 1)  # Quantum Circuit Output

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = self.dropout(x)
        x = x.view(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = self.qnn(x)  # QNN in foward section
        x = self.fc3(x)
        return cat((x, 1 - x), -1)

model = Net(qnn)

# %% [markdown]
# ### GPU Model Activation

# %%
model = model.to('cuda')

# %% [markdown]
# ### Show Model

# %%
print(model)

# %%
summary(model, (3, 260, 260), batch_size=-1, device='cuda')

# %%
# dummy_tensor = next(iter(train_loader))[0].to('cuda')
# make_dot(model(dummy_tensor), params=dict(list(model.named_parameters())), show_saved=True, show_attrs=True).render("rnn_torchviz", format="png")
#Image('https://raw.githubusercontent.com/contepablod/QCNNCancerClassifier/master/rnn_torchviz.png')
Image(r'C:\Users\conte\OneDrive\Escritorio\qiskit-fall-fest-peru-2022-main\qiskit-community-tutorials-master\qiskit-community-tutorials-master\drafts\rnn_torchviz.png', width=2000, height=2250)

# %% [markdown]
# ### Optimisation and Loss Function Definition, and finally training

# %%
optimizer = optim.Adam(model.parameters(), lr=0.00001)
loss_func = CrossEntropyLoss().to('cuda')


epochs = 50
model.train()

loss_list = []
total_accuracy = []

for epoch in range(epochs):
    correct = 0
    total_loss = []
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad(set_to_none=True)
        output = model(data.to('cuda'))  # Forward pass, Data to GPU
        loss = loss_func(output, target.to('cuda')) #Labels to GPU
        loss.backward()  # Backward pass
        optimizer.step()
        total_loss.append(loss.item())
        train_pred = output.argmax(dim=1, keepdim=True)
        correct += train_pred.eq(target.to('cuda').view_as(train_pred)).sum().item()
    loss_list.append(sum(total_loss) / len(total_loss))
    accuracy = 100 * correct / len(train_loader)
    total_accuracy.append(accuracy)
    print(f"Training [{100.0 * (epoch + 1) / epochs:.0f}%]\tLoss: {loss_list[-1]:.4f}\tAccuracy: {accuracy:.2f}%")

# %% [markdown]
# ### Convergence Plot

# %%
fig, ax1 = plt.subplots()
ax1.plot(loss_list, 'g-')
ax2 = ax1.twinx()
ax2.plot(total_accuracy, 'b')
plt.title("Hybrid NN Training Convergence", color='red')
ax1.set_xlabel("Training Iterations")
ax1.set_ylabel("Cross Entropy Loss", color='g')
ax2.set_ylabel("Accuracy (%)", color='b')
plt.show()

# %% [markdown]
# ### Save Model

# %%
torch.save(model.state_dict(), "model.pt")

# %% [markdown]
# ### Load Model to prediction

# %%
qnn1 = create_qnn()
model1 = Net(qnn1)
model1.load_state_dict(torch.load("model.pt"))
model1= model1.to('cuda')

# %%
batch_size=1

model1.eval()
pred_targets = []
test_targets= []
with no_grad():

    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        output = model1(data.to('cuda'))
        if len(output.shape) == 1:
            output = output.reshape(1, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)
        pred_targets.append(pred.item())
        test_targets.append(target.item())
        correct += pred.eq(target.to('cuda').view_as(pred)).sum().item()

        loss = loss_func(output, target.to('cuda'))
        total_loss.append(loss.item())

    print(f"Performance on test data:\n\tLoss: {sum(total_loss) / len(total_loss):.4f}\n\tAccuracy: {100 * correct / len(test_loader) / batch_size:.2f}%")

# %% [markdown]
# ### Show predicted images

# %%
from PIL import Image

n_samples_show = 6
count = 0
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 3))

model1.eval()
with no_grad():
    for batch_idx, (data, target) in enumerate(test_loader):
        if count == n_samples_show:
            break
        output = model1(data.to('cuda')[0:1])
        if len(output.shape) == 1:
            output = output.reshape(3, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)

        axes[count].imshow(torchvision.transforms.ToPILImage(mode='RGB')(data[0].squeeze()), cmap=plt.cm.rainbow)

        axes[count].set_xticks([])
        axes[count].set_yticks([])
        axes[count].set_title("Predicted {}".format(pred.item()))

        count += 1

# %%
matrix_confusion(test_targets, pred_targets)
